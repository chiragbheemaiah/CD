# %% [markdown]
# <a href="https://colab.research.google.com/github/CashBlack7/CD/blob/main/Pytesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install poppler-utils
# !sudo apt-get install tesseract-ocr
# !pip install pdf2image
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.14 [154 kB]
# Fetched 154 kB in 1s (281 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
from pdf2image import convert_from_path
from pytesseract import image_to_string
from PIL import Image

# %%
def convert_pdf_to_img(pdf_file):
    """
    @desc: this function converts a PDF into Image
    
    @params:
        - pdf_file: the file to be converted
    
    @returns:
        - an interable containing image format of all the pages of the PDF
    """
    return convert_from_path(pdf_file)

# %%
def convert_image_to_text(file):
    """
    @desc: this function extracts text from image
    
    @params:
        - file: the image file to extract the content
    
    @returns:
        - the textual content of single image
    """
    
    text = image_to_string(file)
    return text

# %%
def get_text_from_any_pdf(pdf_file):
    """
    @desc: this function is our final system combining the previous functions
    
    @params:
        - file: the original PDF File
    
    @returns:
        - the textual content of ALL the pages
    """
    images = convert_pdf_to_img(pdf_file)
    final_text = ""
    for pg, img in enumerate(images):
        
        final_text += convert_image_to_text(img)
        # print("Page n°{}".format(pg))
        #print(convert_image_to_text(img))
    
    return final_text

# %%
original_path = 'Source.pdf'
modified_path = 'Destination.pdf'

# %%
# print(get_text_from_any_pdf(path_to_pdf))
s = get_text_from_any_pdf(original_path).split('\n')
d = get_text_from_any_pdf(modified_path).split('\n')

# %%
# s

# %%
s1 = [i for i in s if i not in ['\x0c ', '', ' ', '\x0c', '    ']]

# %%
d1 = [i for i in d if i not in ['\x0c ', '', ' ', '\x0c', '    ']]

# %%
s1

# %%
s2 = [f"{i+1}. {sentence}" for i, sentence in enumerate(s1)]

# %%
s2

# %%
d1

# %%
d2 = [f"{i+1}. {sentence}" for i, sentence in enumerate(d1)]

# %%
d2
# Out:
# ['1. Types of Agreements',
#  '2. A “contract” is a legally binding agreement between two or more parties obligating parties to do',
#  '3. or not to do a particular thing. A contract may be verbal or written, formal or informal, general or',
#  '4. detailed. A contract may be labeled under various names (agreement, contract, purchase order,',
#  '5. terms and conditions, letter of intent, authorization to proceed, award, grant etc.). If the',
#  '6. university is obligated in any way to perform a service or receive a service a contract should be',
#  '7. negotiated by the appropriate university office at Nagpur. The only parties allowed to enter',
#  '8. into a contract on behalf of the university are individuals that have been given signature',
#  '9. authority by the Board of Trustees. The Office for Soonsored Programs negotiates',
#  '10. contracts/agreements for research projects in conjunction with the Office of Counsel, the Office',
# ...

# %%
# d

# %%
# og_text = []
# for ele in s:
#     if ele.isalpha():
#       og_text.append(ele.lower()) 
#     else:
#       temp = ""
#       for i in ele: 
#         if i.isalpha() or i.isnumeric():
#           temp = temp + i
#       if temp != "":
#         og_text.append(temp.lower())

# %%
# mod_text = []
# for ele in d:
#     if ele.isalpha():
#       mod_text.append(ele.lower()) 
#     else:
#       temp = ""
#       for i in ele: 
#         if i.isalpha() or i.isnumeric():
#           temp = temp + i
#       if temp != "":
#         mod_text.append(temp.lower())

# %%
import difflib as dl

# %%
diff_items = dl.ndiff(s2, d2)

for diff in diff_items:
  print(diff)
# Out:
#   1. Types of Agreements
#   2. A “contract” is a legally binding agreement between two or more parties obligating parties to do
#   3. or not to do a particular thing. A contract may be verbal or written, formal or informal, general or
# - 4. detailed. A contract can also be labeled under various names (agreement, contract, purchase
# ?                         ^ ^^^^^^
#
# + 4. detailed. A contract may be labeled under various names (agreement, contract, purchase order,
# ?                         ^ ^                                                              +++++++
#
# - 5. order, terms and conditions, letter of intent, authorization to proceed, award, grant etc.). If the
# ?   -------
#
# + 5. terms and conditions, letter of intent, authorization to proceed, award, grant etc.). If the
#   6. university is obligated in any way to perform a service or receive a service a contract should be
# ...

# %%
# print(result)

# %%
# result.split()

# %%
src = []
dest = []
d1 = dict()
d2 = dict()
for i in og_text:
    if i not in d1.keys():
        d1[i] = 1
    else:
        d1[i] = d1[i] + 1
        
for i in mod_text:
    if i not in d2.keys():
        d2[i] = 1
    else:
        d2[i] = d2[i] + 1
        

for i in d1.keys():
    if i not in d2.keys():
        src.append(i)
    else:
        if d1[i] > d2[i]:
          for _ in range(d1[i] - d2[i]):
            src.append(i)
            
for i in d2.keys():
    if i not in d1.keys():
        dest.append(i)
    else:
        if d2[i] > d1[i]:
          for _ in range(d2[i] - d1[i]):
            dest.append(i)

# %%
print("New Document modifications: " + str(src))
# Out:
# New Document modifications: ['between', 'or', 'can', 'also', 'office', 'sponsored', 'programs', 'transfer', 'transfer', '2053487812', 'project', 'sponsorfunding', 'pils', 'no', 'giving', 'education', 'scope', 'modification', 'all', 'osp', 'small', 'program', 'ii', 'teaming', 'prime']

# %%
print("Previous Document changed: " + str(dest))
# Out:
# Previous Document changed: ['of', 'two', 'not', 'at', 'at', 'nagpur', 'soonsored', '2053582187', 'funding', 'researchoriented', 'fund', 'oroject', 'pis', 'acquisition', 'merger', '50000', 'programmmes', 'one', 'maymay', 'scopeof', 'offices', 'ospof', 'party', 'il', 'betwixt', 'medium', 'primary', 'confirms', 'least']
